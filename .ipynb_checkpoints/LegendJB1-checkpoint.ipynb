# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *

# %%
# 데이터 불러오기
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
submiss_sam = pd.read_csv('sample_submission.csv')

# %%
train
# Out:
#             ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0    TRAIN_000            4      103             60             33      192
# 1    TRAIN_001           10      133             68              0        0
# 2    TRAIN_002            4      112             78             40        0
# 3    TRAIN_003            1      119             88             41      170
# 4    TRAIN_004            1      114             66             36      200
# ..         ...          ...      ...            ...            ...      ...
# 647  TRAIN_647            1       91             64             24        0
# 648  TRAIN_648           10      122             68              0        0
# 649  TRAIN_649            8       84             74             31        0
# 650  TRAIN_650            2       81             72             15       76
# 651  TRAIN_651            1      107             68             19        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 0    24.0                     0.966   33        0
# 1    27.0                     0.245   36        0
# 2    39.4                     0.236   38        0
# 3    45.3                     0.507   26        0
# 4    38.1                     0.289   21        0
# ..    ...                       ...  ...      ...
# 647  29.2                     0.192   21        0
# 648  31.2                     0.258   41        0
# 649  38.3                     0.457   39        0
# 650  30.1                     0.547   25        0
# 651  26.5                     0.165   24        0
#
# [652 rows x 10 columns]

# %%
def replace_zeros_with_mean(df):
    updated_df = df.copy()  # 데이터프레임의 복사본 생성
    for column in updated_df.columns[2:-1]:  # 첫 번째 열(ID), 임신횟수와 마지막 열(Outcome)을 제외한 모든 열에 대해 반복
        mean_value = updated_df[column][updated_df[column] != 0].mean()  # 0이 아닌 값들의 평균 계산
        updated_df[column] = updated_df[column].replace(0, mean_value)  # 0 값을 평균값으로 대체
    return updated_df

# 0 값을 평균값으로 대체하는 함수 적용
updated_train = replace_zeros_with_mean(train)

updated_test = replace_zeros_with_mean(test)
display(updated_train,updated_test)
# Out:
#             ID  Pregnancies  Glucose  BloodPressure  SkinThickness  \
# 0    TRAIN_000            4    103.0           60.0      33.000000
# 1    TRAIN_001           10    133.0           68.0      29.161926
# 2    TRAIN_002            4    112.0           78.0      40.000000
# 3    TRAIN_003            1    119.0           88.0      41.000000
# 4    TRAIN_004            1    114.0           66.0      36.000000
# ..         ...          ...      ...            ...            ...
# 647  TRAIN_647            1     91.0           64.0      24.000000
# 648  TRAIN_648           10    122.0           68.0      29.161926
# 649  TRAIN_649            8     84.0           74.0      31.000000
# 650  TRAIN_650            2     81.0           72.0      15.000000
# 651  TRAIN_651            1    107.0           68.0      19.000000
#
#         Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0    192.000000  24.0                     0.966   33        0
# 1    157.883234  27.0                     0.245   36        0
# 2    157.883234  39.4                     0.236   38        0
# 3    170.000000  45.3                     0.507   26        0
# 4    200.000000  38.1                     0.289   21        0
# ..          ...   ...                       ...  ...      ...
# 647  157.883234  29.2                     0.192   21        0
# 648  157.883234  31.2                     0.258   41        0
# 649  157.883234  38.3                     0.457   39        0
# 650   76.000000  30.1                     0.547   25        0
# 651  157.883234  26.5                     0.165   24        0
#
# [652 rows x 10 columns]
#            ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0    TEST_000            5    112.0       66.00000      29.107143   142.55
# 1    TEST_001            3    107.0       62.00000      13.000000    48.00
# 2    TEST_002            3    113.0       44.00000      13.000000   142.55
# 3    TEST_003            6    190.0       92.00000      29.107143   142.55
# 4    TEST_004            1    107.0       72.00000      30.000000    82.00
# ..        ...          ...      ...            ...            ...      ...
# 111  TEST_111           10    111.0       70.00000      27.000000   142.55
# 112  TEST_112            1    119.0       54.00000      13.000000    50.00
# 113  TEST_113            3    187.0       70.00000      22.000000   200.00
# 114  TEST_114            3    100.0       68.00000      23.000000    81.00
# 115  TEST_115            2     84.0       73.45045      29.107143   142.55
#
#            BMI  DiabetesPedigreeFunction  Age
# 0    37.800000                     0.261   41
# 1    22.900000                     0.678   23
# 2    22.400000                     0.140   22
# 3    35.500000                     0.278   66
# 4    30.800000                     0.821   24
# ..         ...                       ...  ...
# 111  27.500000                     0.141   40
# 112  22.300000                     0.205   24
# 113  36.400000                     0.408   36
# 114  31.600000                     0.949   28
# 115  33.398214                     0.304   21
#
# [116 rows x 9 columns]

# %%
fig = plt.Figure()

# %%
ggplot(updated_train, aes(x='Glucose', y='BMI',color='Outcome')) + geom_point()

# %%
updated_train[updated_train['BMI']<10]
# Out:
# Empty DataFrame
# Columns: [ID, Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
train.columns
# Out:
# Index(['ID', 'Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
#        'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
train['Pregnancies']/train['Age']
# Out:
# 0      0.121212
# 1      0.277778
# 2      0.105263
# 3      0.038462
# 4      0.047619
#          ...
# 647    0.047619
# 648    0.243902
# 649    0.205128
# 650    0.080000
# 651    0.041667
# Length: 652, dtype: float64

# %%
train['Pre1'] =  (train['Pregnancies']/train['Age'])
train['Glu1'] =  (train['Glucose']/train['DiabetesPedigreeFunction'])
train['Age1'] = (train['Age']/train['DiabetesPedigreeFunction'])

# %%
train
# Out:
#             ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0    TRAIN_000            4      103             60             33      192
# 1    TRAIN_001           10      133             68              0        0
# 2    TRAIN_002            4      112             78             40        0
# 3    TRAIN_003            1      119             88             41      170
# 4    TRAIN_004            1      114             66             36      200
# ..         ...          ...      ...            ...            ...      ...
# 647  TRAIN_647            1       91             64             24        0
# 648  TRAIN_648           10      122             68              0        0
# 649  TRAIN_649            8       84             74             31        0
# 650  TRAIN_650            2       81             72             15       76
# 651  TRAIN_651            1      107             68             19        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome      Pre1        Glu1  \
# 0    24.0                     0.966   33        0  0.121212  106.625259
# 1    27.0                     0.245   36        0  0.277778  542.857143
# 2    39.4                     0.236   38        0  0.105263  474.576271
# 3    45.3                     0.507   26        0  0.038462  234.714004
# 4    38.1                     0.289   21        0  0.047619  394.463668
# ..    ...                       ...  ...      ...       ...         ...
# 647  29.2                     0.192   21        0  0.047619  473.958333
# 648  31.2                     0.258   41        0  0.243902  472.868217
# 649  38.3                     0.457   39        0  0.205128  183.807440
# 650  30.1                     0.547   25        0  0.080000  148.080439
# 651  26.5                     0.165   24        0  0.041667  648.484848
#
#            Age1
# 0     34.161491
# 1    146.938776
# 2    161.016949
# 3     51.282051
# 4     72.664360
# ..          ...
# 647  109.375000
# 648  158.914729
# 649   85.339168
# 650   45.703839
# 651  145.454545
#
# [652 rows x 13 columns]

# %%
test['Pre1'] = (test['Pregnancies'] / test['Age'])
test['Glu1'] = (test['Glucose'] / test['DiabetesPedigreeFunction'])
test['Age1'] = (test['Age'] / test['DiabetesPedigreeFunction'])

# %%
x = train.drop("Outcome",axis=1)
y = pd.DataFrame(train.Outcome)

# %%
from sklearn.preprocessing import LabelEncoder

Label = LabelEncoder()

for i in y.columns:
    y[i] = Label.fit_transform(y[i])

# %%
y = train.Outcome

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# train-test split
X_train, X_test, y_train, y_test = train_test_split(train, y, test_size=0.3, random_state=42)

rf = RandomForestClassifier()
param_grid = { 'n_estimators':[200,700], 'max_features':['auto','sqrt','log2']

             }
rfc = GridSearchCV(estimator=rf,param_grid=param_grid, cv=5)
rfc .fit(X_train,y_train)
# 테스트 데이터에 대한 예측
y_pred = rfc.predict(X_test)

# 모델 성능 평가 (예시로 평균 제곱 오차 사용)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
np.round(y_pred,2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 16
#      12 param_grid = { 'n_estimators':[200,700], 'max_features':['auto','sqrt','log2']
#      13
#      14              }
#      15 rfc = GridSearchCV(estimator=rf,param_grid=param_grid, cv=5)
# ---> 16 rfc .fit(X_train,y_train)
#      17 # 테스트 데이터에 대한 예측
#      18 y_pred = rfc.predict(X_test)
#
# File ~/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File ~/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1527, in GridSearchCV._run_search(self, evaluate_candidates)
#    1525 def _run_search(self, evaluate_candidates):
#    1526     """Search all candidates in param_grid"""
# -> 1527     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/model_selection/_search.py:947, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     940 elif len(out) != n_candidates * n_splits:
#     941     raise ValueError(
#     942         "cv.split and cv.get_n_splits returned "
#     943         "inconsistent results. Expected {} "
#     944         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     945     )
# --> 947 _warn_or_raise_about_fit_failures(out, self.error_score)
#     949 # For callable self.scoring, the return type is only know after
#     950 # calling. If the return type is a dictionary, the error scores
#     951 # can now be inserted with the correct key. The type checking
#     952 # of out will be done in `_insert_error_scores`.
#     953 if callable(self.scoring):
#
# File ~/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:531, in _warn_or_raise_about_fit_failures(results, error_score)
#     524 if num_failed_fits == num_fits:
#     525     all_fits_failed_message = (
#     526         f"\nAll the {num_fits} fits failed.\n"
#     527         "It is very likely that your model is misconfigured.\n"
#     528         "You can try to debug the error by setting error_score='raise'.\n\n"
#     529         f"Below are more details about the failures:\n{fit_errors_summary}"
#     530     )
# --> 531     raise ValueError(all_fits_failed_message)
#     533 else:
#     534     some_fits_failed_message = (
#     535         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     536         "The score on these train-test partitions for these parameters"
#    (...)
#     540         f"Below are more details about the failures:\n{fit_errors_summary}"
#     541     )
#
# ValueError:
# All the 30 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 890, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/base.py", line 1344, in wrapper
#     estimator._validate_params()
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 890, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/base.py", line 1351, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/ensemble/_forest.py", line 363, in fit
#     X, y = self._validate_data(
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/base.py", line 650, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/utils/validation.py", line 1192, in check_X_y
#     X = check_array(
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/utils/validation.py", line 951, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 521, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/pandas/core/generic.py", line 2084, in __array__
#     arr = np.asarray(values, dtype=dtype)
# ValueError: could not convert string to float: 'TRAIN_586'
#
# --------------------------------------------------------------------------------
# 16 fits failed with the following error:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 890, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/base.py", line 1351, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/ensemble/_forest.py", line 363, in fit
#     X, y = self._validate_data(
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/base.py", line 650, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/utils/validation.py", line 1192, in check_X_y
#     X = check_array(
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/utils/validation.py", line 951, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/sklearn/utils/_array_api.py", line 521, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "/root/anaconda3/envs/deep/lib/python3.10/site-packages/pandas/core/generic.py", line 2084, in __array__
#     arr = np.asarray(values, dtype=dtype)
# ValueError: could not convert string to float: 'TRAIN_450'
